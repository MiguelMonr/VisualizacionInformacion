# %% [markdown]
# ## La libreria que se usa es
# `ggplot()`

# %% [markdown]
# ggplot funciona por capas. En este caso el orden de las capas si altera el resultado final

# %%
#Este es un ejemplo
library(ggplot2)
ggplot(data = economics, aes(x = date, y = unemploy)) + #*Aqui en el + es donde se ponen las apas
    geom_point()
# Out:
# plot without title

# %% [markdown]
# Metodos importantes al trabajar con graficas:
# - Para temas de imagen usas la funcion `aes()`
# - En `aes()` pones las columnas que quieres graficar.
# Dentro de la funcion de aes puedes elegir el color de la linea y el relleno
# - Tipo de linea: `type=`
# - Para elegir el color del relleno: `fill= `
# - Para elegir el color de la linea: `col= `

# %%
miGraf <- ggplot(data = mtcars, aes(x = wt, y = mpg))

miGraf +
    geom_point(size = 2, color = "red") +
    geom_smooth(method = "lm", se = FALSE)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## IMPORTANTE
#
# Si bien `fill`y `col` tienen la misma funcion depende mucho el tipo de grafica el parametro que vamos utilizar.
#
# - Col se usa en las siguientes graficas: scatter plots, lineas
# - fill se usa para establecer el color del interior de los objetos que tienen un área rellenable: barras, boxplots, densidad

# %% [markdown]
# # Para poner leyendas
# `labs()`

# %%
miGraf <- ggplot(data = mtcars, aes(x = wt, y = mpg))

miGraf +
    geom_point(size = 2, color = "red") +
    geom_smooth(method = "lm", se = FALSE) +
        labs("Nuevo Título", x= "prueba1", y= "prueba2") #! Aqui esta para ponerle el titulo
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # Graficas de primer parcial

# %% [markdown]
# Grafica de dispersion

# %%
miGraf <- ggplot(data = mtcars, aes(x = wt, y = mpg)) #Aqui estableces las variables de cada eje

miGraf +
    geom_point(size = 2) + #* El tamaño del punto
    geom_smooth(method = "lm", se = FALSE)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # Bubble plot

# %%
miGraf <- ggplot(mtcars, aes(wt, mpg, size = disp)) #* Es en size 
miGraf +
    geom_point(alpha = 0.5) + #* Aqui escoge la transparencia
    scale_size(range = c(1, 10)) #! cuantos tamaños quieres
# Out:
# plot without title

# %% [markdown]
# ## Grafica de puntos y lineas

# %%
install.packages("hrbrthemes")
# Out:
# also installing the dependencies 'fontBitstreamVera', 'fontLiberation', 'extrafontdb', 'Rttf2pt1', 'gfonts', 'fontquiver', 'extrafont', 'gdtools'
# The downloaded binary packages are in
# 	/var/folders/81/3z5tmwbd7sq0s2qmqph5c0c80000gn/T//Rtmp7tRz7o/downloaded_packages

# %%
library(hrbrthemes)
library(dplyr)
# Out:
# Adjuntando el paquete: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
data <- read.table("https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/3_TwoNumOrdered.csv", header = T)
data$date <- as.Date(data$date)

data %>%
    tail(10) %>%
    ggplot(aes(x = date, y = value)) +
    geom_line(color = "grey") +
    geom_point(shape = 21, color = "black", fill = "#69b3a2", size = 6) +
    theme_ipsum() +
    ggtitle("Evolution of bitcoin price")
# Out:
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# "font family 'Arial Narrow' not found in PostScript font database"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# "font family 'Arial Narrow' not found in PostScript font database"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# "font family 'Arial Narrow' not found in PostScript font database"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# "font family 'Arial Narrow' not found in PostScript font database"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# "font family 'Arial Narrow' not found in PostScript font database"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# "font family 'Arial Narrow' not found in PostScript font database"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# ...

# %% [markdown]
# # Grafica de barras

# %% [markdown]
# **importante** geom_bar por default tiene a generar un histograma

# %%
miGraf <- ggplot(mpg, aes(x = class))
miGraf + geom_bar(fill = "cyan")
# Out:
# plot without title

# %%
#Usando patchworks
library(patchwork) #Este se usa para concatenarlas graficas 

df <- data.frame(scouts = c("Ruben", "Adaya", "Victor", "Dario"), ventas = c(380, 350, 320, 410))

# Lo que veniamos haciendo
p1 <- ggplot(df, aes(x = scouts)) +
    geom_bar()

# Lo que debemos hacer
p2 <- ggplot(df, aes(x = scouts, y = ventas)) +
    geom_bar(stat = "identity") #! Se usa identity para graficar 

p1 + p2
# Out:
# plot without title

# %% [markdown]
# # Barras apiladas

# %%
#En x va el tipo de clase, en y nada y queremos rellenarlo con los tipos de traccion
miGraf <- ggplot(mpg, aes(x = class, fill = drv))

miGraf + geom_bar()
# Out:
# Error in library(forcats): no hay paquete llamado 'forcats'
# Traceback:
#
# 1. library(forcats)
# plot without title

# %%
#Manera alterno usando otra libreria
install.packages("forcats")
# Out:
# The downloaded binary packages are in
# 	/var/folders/81/3z5tmwbd7sq0s2qmqph5c0c80000gn/T//Rtmp7tRz7o/downloaded_packages

# %%
library(forcats)
#En el eje y va a ir "cuanto se repite" la clase
miGraf <- ggplot(mpg, aes(x = fct_infreq(class))) 
miGraf <- miGraf + geom_bar(aes(fill = drv)) #Elegimos que el relleno sea la traccion

miGraf + scale_fill_brewer(palette = "Pastel1")
# Out:
# plot without title

# %% [markdown]
# # Steamgraph

# %%
install.packages("ggstream")
# Out:
# The downloaded binary packages are in
# 	/var/folders/81/3z5tmwbd7sq0s2qmqph5c0c80000gn/T//Rtmp7tRz7o/downloaded_packages

# %%
library(ggstream)

miGraf <- ggplot(blockbusters, aes(year, box_office, fill = genre))
miGraf + geom_stream()
# Out:
# plot without title

# %%
#Alternativas
miGraf + geom_bar(stat = "identity") #* Con barras

# opcion areas
miGraf + geom_area(alpha = 0.3)
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Heatmaps
# *IMPORTANTE* Para heatmaps los datos tienen que estar en formato wide&long

# %%
install.packages("reshape2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/81/3z5tmwbd7sq0s2qmqph5c0c80000gn/T//Rtmp7tRz7o/downloaded_packages

# %%
library(reshape2)
library(tidyr)

# agregamos col. Nombre auto
mtdf <- melt(mtcars) #! Este es importante 
mtdf$car <- rep(row.names(mtcars), 11)
head(mtdf)


# Tenemos que rescalar (0 a 1) porque los valores de un atributo (disp) son
#  mucho mayors que los demás
library(plyr)
library(dplyr)
library(scales)
mtdf <- ddply(mtdf, .(variable), transform, rescale = rescale(value))
# crea mapa
miGraf <- ggplot(mtdf, aes(variable, car))
miGraf + geom_tile(aes(fill = rescale), colour = "white") +
    scale_fill_gradient(low = "white", high = "steelblue")
# Out:
# Adjuntando el paquete: 'tidyr'
#
#
# The following object is masked from 'package:reshape2':
#
#     smiths
#
#
# No id variables; using all as measure variables
#   variable value car
# 1 mpg      21.0  Mazda RX4
# 2 mpg      21.0  Mazda RX4 Wag
# 3 mpg      22.8  Datsun 710
# 4 mpg      21.4  Hornet 4 Drive
# 5 mpg      18.7  Hornet Sportabout
# 6 mpg      18.1  Valiant
# ------------------------------------------------------------------------------
#
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
#
# ------------------------------------------------------------------------------
#
#
# Adjuntando el paquete: 'plyr'
#
#
# The following objects are masked from 'package:dplyr':
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
# plot without title
